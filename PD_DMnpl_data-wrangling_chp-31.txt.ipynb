# %%
import pandas as pd
import numpy as np
from numpy import*

# %%
df=pd.read_table('D:\Practice Pandas\Data Analysis\data-wrangling_chp-31.txt', sep=',')
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1=pd.read_table(r'D:\Practice Pandas\Data Analysis\berlin_weather_oldest-1.txt', sep=',')
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %% [markdown]
# ### 1. Get the Metadata from the above files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# ### 2. Get the row names from the above files.

# %%
df1.index                                           # in range-index form
# Out:
# RangeIndex(start=0, stop=117208, step=1)

# %%
type(df1.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4656, step=1)

# %% [markdown]
# ### 3. Change the column name from any of the above file.

# %%
df.columns=df.columns.str.replace('Indicator', 'Indicator_Id')
df.head()
# Out:
#                         Indicator_Id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ### 4. Change the names of multiple columns.

# %%
#co=['Indicator_Id', 'Publish_States', 'WHO_region', 'World_Bank_Income_Group', 'Country', 'Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments']
dc=pd.DataFrame(df, columns=['Indicator_Id', 'Publish_States', 'WHO_region', 'World_Bank_Income_Group', 'Country', 'Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments'])
dc.head()
# Out:
#                         Indicator_Id  Publish_States  WHO_region  \
# 0   Life expectancy at birth (years)             NaN         NaN
# 1   Life expectancy at birth (years)             NaN         NaN
# 2  Life expectancy at age 60 (years)             NaN         NaN
# 3  Life expectancy at age 60 (years)             NaN         NaN
# 4   Life expectancy at birth (years)             NaN         NaN
#
#    World_Bank_Income_Group               Country         Sex  Display Value  \
# 0                      NaN               Andorra  Both sexes             77
# 1                      NaN               Andorra  Both sexes             80
# 2                      NaN               Andorra      Female             28
# 3                      NaN               Andorra  Both sexes             23
# 4                      NaN  United Arab Emirates      Female             78
#
#    Numeric  Low  High  Comments
# 0     77.0  NaN   NaN       NaN
# 1     80.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ### 5. Arrange values of a particular column in ascending order.

# %%
df.sort_values('Year', ascending=True)
# Out:
#                                          Indicator_Id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1270                 Life expectancy at birth (years)      Published  1990
# 3193                 Life expectancy at birth (years)      Published  1990
# 3194                 Life expectancy at birth (years)      Published  1990
# 3197                Life expectancy at age 60 (years)      Published  1990
# 1264                 Life expectancy at birth (years)      Published  1990
# 3199                Life expectancy at age 60 (years)      Published  1990
# 1262                Life expectancy at age 60 (years)      Published  1990
# 1259                 Life expectancy at birth (years)      Published  1990
# 3203                Life expectancy at age 60 (years)      Published  1990
# 1273                Life expectancy at age 60 (years)      Published  1990
# ...

# %% [markdown]
# ### 7. Arrange multiple column values in ascending order.

# %%
df.sort_values(['Indicator_Id','Country', 'Year', 'WHO region', 'PUBLISH STATES'], ascending=[True, True, True, True, True])
# Out:
#                                          Indicator_Id PUBLISH STATES  Year  \
# 2798  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 3363  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4456  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 2245  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 3689  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4457  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 2598  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 3690  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 3691  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 2599  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 3692  Healthy life expectancy (HALE) at birth (years)      Published  2012
# ...

# %% [markdown]
# ### 7. Make country as the first column of the dataframe.

# %%
df.set_index('Country')
# Out:
#                                                                        Indicator_Id  \
# Country
# Andorra                                            Life expectancy at birth (years)
# Andorra                                            Life expectancy at birth (years)
# Andorra                                           Life expectancy at age 60 (years)
# Andorra                                           Life expectancy at age 60 (years)
# United Arab Emirates                               Life expectancy at birth (years)
# Antigua and Barbuda                                Life expectancy at birth (years)
# Antigua and Barbuda                               Life expectancy at age 60 (years)
# Antigua and Barbuda                               Life expectancy at age 60 (years)
# Australia                                          Life expectancy at birth (years)
# Australia                                          Life expectancy at birth (years)
# ...

# %% [markdown]
# ### 8. Get the column array using a variable

# %%
fgh=np.array(df['Country'])
fgh
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# ### 9. Get the subset rows 11, 24, 37

# %%
df.iloc[[11,24,37]]
# Out:
#                          Indicator_Id PUBLISH STATES  Year       WHO region  \
# 11   Life expectancy at birth (years)      Published  2012           Europe
# 24  Life expectancy at age 60 (years)      Published  2012  Western Pacific
# 37  Life expectancy at age 60 (years)      Published  2012           Europe
#
#    World Bank income group            Country     Sex  Display Value  Numeric  \
# 11             High-income            Austria  Female             83     83.0
# 24             High-income  Brunei Darussalam  Female             21     21.0
# 37             High-income             Cyprus  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %% [markdown]
# ### 10. Get the subset rows excluding 5, 12, 23, and 56

# %%
df.drop([5,12,23,56], axis=0)
# Out:
#                                          Indicator_Id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# 11                   Life expectancy at birth (years)      Published  2012
# ...

# %% [markdown]
# # Load datasets from CSV
# * users
# * transextions
# * session
# * products

# %%
dfu=pd.read_csv(r'D:\\Practice Pandas\\Data Analysis\\Data Wrangling\\users.csv', sep='\,')
dft=pd.read_csv(r'D:\\Practice Pandas\\Data Analysis\\Data Wrangling\\transections.csv', sep='\,')
dfs=pd.read_csv(r'D:\\Practice Pandas\\Data Analysis\\Data Wrangling\\session.csv', sep='\,')
dfp=pd.read_csv(r'D:\\Practice Pandas\\Data Analysis\\Data Wrangling\\products.csv', sep='\,')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ...

# %%
dfu
# Out:
#   """UserID""      ""User""  ""Gender"" ""Registered"" ""Cancelled"""
# 0          "1   ""Charles""    ""male""     2012-12-21            NA"
# 1          "2     ""Pedro""    ""male""     2010-08-01    2010-08-08"
# 2          "3  ""Caroline""  ""female""     2012-10-23    2016-06-07"
# 3          "4   ""Brielle""  ""female""     2013-07-17            NA"
# 4          "5  ""Benjamin""    ""male""     2010-11-25            NA"
# 5          "6    2013-12-23           2              5             6"
# 6          "7    2013-12-30           3              4             1"

# %%
dft
# Out:
#   """TransactionID"" ""TransactionDate""  ""UserID""  ""ProductID""  \
# 0                 "1          2010-08-21           7              2
# 1                 "2          2011-05-26           3              4
# 2                 "3          2011-06-16           3              3
# 3                 "4          2012-08-26           1              2
# 4                 "5          2013-06-06           2              4
# 5                 "6          2013-12-23           2              5
# 6                 "7          2013-12-30           3              4
#
#   ""Quantity"""
# 0            1"
# 1            1"
# 2            1"
# 3            3"
# 4            1"
# 5            6"
# 6            1"

# %%
dfs
# Out:
#   """SessionID"" ""SessionDate"" ""UserID"""
# 0             "1      2010-01-05          2"
# 1             "2      2010-08-01          2"
# 2             "3      2010-11-25          2"
# 3             "4      2011-09-21          5"
# 4             "5      2011-10-19          4"
# 5             "6      2012-10-23          4"
# 6             "7      2012-12-21          3"
# 7             "8      2013-05-22          4"

# %%
dfp
# Out:
#   """ProductID"" ""Product"" ""Price"""
# 0             "1       ""A""     14.16"
# 1             "2       ""B""     33.04"
# 2             "3       ""C""     10.65"
# 3             "4       ""D""     10.02"
# 4             "5       ""E""     29.66"
